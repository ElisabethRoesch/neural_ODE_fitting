# %%
using  Plots, Optim, Dates, DiffEqParamEstim, Flux, DiffEqFlux, OrdinaryDiffEq, MAT, Statistics

# %%
# Observed data
vars = matread("/Users/eroesch/Dropbox/PhD/year_1/140728_data.mat")
x = mean.(vars[ "NGF5_ppERK"])[1,:]
y = mean.(vars[ "NGF5_ppMEK"])[1,:]
ode_data = transpose(hcat(x,y))
u0 = [x[1],y[1],0.]
tspan = (0.0f0, 1.5f0)
t = range(tspan[1], tspan[2], length = length(x))
species1 = "NGF5_ppERK"
species2 = "NGF5_ppERK";

# %%
mutable struct saver
    losses::Array{Float64,1}
    l2s::Array{Float64,1}
    times::Array{Dates.Time,1}
    count_epochs::Int128
end
function saver(n_epochs)
    losses = zeros(n_epochs)
    l2s = zeros(n_epochs)
    times = fill(Dates.Time(Dates.now()),n_epochs)
    count_epochs = 0
    return saver(losses,l2s,times,count_epochs)
end
function update_saver(saver, loss_i, l2_i, time_i)
    epoch_i = saver.count_epochs
    saver.losses[epoch_i] = loss_i
    saver.l2s[epoch_i] = l2_i
    saver.times[epoch_i] = time_i
end
# Out:
# update_saver (generic function with 1 method)

# %%
scatter(t, ode_data[1,:], grid = "off", xlab = "time", ylab = "Abundance", label = species1)
scatter!(t, ode_data[2,:], label = species2)

# %%
# Building a neural ODE 
# Derivative is modeled by a neural net. Chain concatinates the functions ode function and two dense layers.
dudt = Chain(Dense(3,100,tanh),
       Dense(100,100,tanh),
       Dense(100,100,tanh),
       Dense(100,100,tanh),
       Dense(100,3))
# Parameters of the model which are to be learnt. They are: W1 (2x50), b1 (50), W2 (50x2), b2 (2)
ps = Flux.params(dudt)
# Getting loss function from two stage collocation function
function node_two_stage_function(model, x, tspan, saveat, ode_data,
            args...; kwargs...)
  dudt_(du,u,p,t) = du .= model(u)
  prob_fly = ODEProblem(dudt_,x,tspan)
  two_stage_method(prob_fly, saveat, ode_data)
end
# Rosenbrock23, TRBDF2, ABDF2, Rodas5, Rodas4P, Kvaerno5, KenCarp4, CVODE_BDF (not defined)
loss_n_ode = node_two_stage_function(dudt, u0, tspan, t, ode_data, Rosenbrock23(autodiff=false), reltol=1e-7, abstol=1e-9)
#  loss function
two_stage_loss_fct()=loss_n_ode.cost_function(ps)
# Defining anonymous function for the neural ODE with the model. in: u0, out: solution with current params.
n_ode = x->neural_ode(dudt, x, tspan, Rosenbrock23(autodiff=false), saveat=t, reltol=1e-7, abstol=1e-9)
n_epochs = 5000
verify = 100 # for <verify>th epoch the L2 is calculated  
data1 = Iterators.repeated((), n_epochs)
opt1 = ADAM(0.0001)
sa = saver(n_epochs)
L2_loss_fct() = sum(abs2,ode_data .- n_ode(u0))
# Callback function to observe two stage training.
cb1 = function ()
    sa.count_epochs = sa.count_epochs +  1
    if mod(sa.count_epochs-1, verify)==0
        #update_saver(sa, Tracker.data(two_stage_loss_fct()),Tracker.data(L2_loss_fct()), Dates.Time(Dates.now()))
        # println("\"",Tracker.data(two_stage_loss_fct()),"\" \"",Dates.Time(Dates.now()),"\";")
    else
        update_saver(sa, Tracker.data(two_stage_loss_fct()),0,Dates.Time(Dates.now()))
        # println("\"",Tracker.data(two_stage_loss_fct()),"\" \"",Dates.Time(Dates.now()),"\";")
    end
end
# Out:
# #13 (generic function with 1 method)

# %%
pred = n_ode(u0)
scatter(t, ode_data[1,:], label = string("Observation: ", species1), grid = "off")
scatter!(t, ode_data[2,:], label = string("Observation: ", species2))
plot!(t, Flux.data(pred[1,:]), label = string("Prediction: ", species1))
plot!(t, Flux.data(pred[2,:]), label = string("Prediction: ", species2))

# %%
# train n_ode with collocation method
@time Flux.train!(two_stage_loss_fct, ps, data1, opt1, cb = cb1)
# Out:
# DimensionMismatch("second dimension of A, 3, does not match length of x, 2")
#
# Stacktrace:
#  [1] gemv!(::Array{Float32,1}, ::Char, ::Array{Float32,2}, ::Array{Float32,1}) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.0/LinearAlgebra/src/matmul.jl:349
#  [2] * at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.0/LinearAlgebra/src/matmul.jl:64 [inlined]
#  [3] _forward at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/lib/array.jl:390 [inlined]
#  [4] #track#1 at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/Tracker.jl:51 [inlined]
#  [5] track at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/Tracker.jl:51 [inlined]
#  [6] * at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/lib/array.jl:382 [inlined]
#  [7] Dense at /Users/eroesch/.julia/packages/Flux/qXNjB/src/layers/basic.jl:99 [inlined]
#  [8] Dense at /Users/eroesch/.julia/packages/Flux/qXNjB/src/layers/basic.jl:110 [inlined]
#  [9] (::Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}})(::SubArray{Float64,1,Array{Float64,2},Tuple{Base.Slice{Base.OneTo{Int64}},Int64},true}) at /Users/eroesch/.julia/packages/Flux/qXNjB/src/layers/basic.jl:113
#  [10] applychain(::Tuple{Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(identity),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}}}, ::SubArray{Float64,1,Array{Float64,2},Tuple{Base.Slice{Base.OneTo{Int64}},Int64},true}) at /Users/eroesch/.julia/packages/Flux/qXNjB/src/layers/basic.jl:31
#  [11] Chain at /Users/eroesch/.julia/packages/Flux/qXNjB/src/layers/basic.jl:33 [inlined]
#  [12] (::getfield(Main, Symbol("#dudt_#10")){Chain{Tuple{Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(identity),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}}}}})(::Array{Any,1}, ::SubArray{Float64,1,Array{Float64,2},Tuple{Base.Slice{Base.OneTo{Int64}},Int64},true}, ::Tracker.Params, ::Float32) at ./In[11]:13
#  [13] (::ODEFunction{true,getfield(Main, Symbol("#dudt_#10")){Chain{Tuple{Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(identity),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}}}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing})(::Array{Any,1}, ::SubArray{Float64,1,Array{Float64,2},Tuple{Base.Slice{Base.OneTo{Int64}},Int64},true}, ::Vararg{Any,N} where N) at /Users/eroesch/.julia/packages/DiffEqBase/DqkH4/src/diffeqfunction.jl:193
#  [14] (::getfield(DiffEqParamEstim, Symbol("##44#49")){ODEProblem{Array{Float64,1},Tuple{Float32,Float32},true,Nothing,ODEFunction{true,getfield(Main, Symbol("#dudt_#10")){Chain{Tuple{Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(tanh),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dense{typeof(identity),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}}}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},StepRangeLen{Float32,Float64,Float64},Int64,Array{Float64,2},Array{Float64,2}})(::Tracker.Params) at /Users/eroesch/.julia/packages/DiffEqParamEstim/mNjO8/src/two_stage_method.jl:94
#  [15] two_stage_loss_fct() at ./In[11]:20
#  [16] #15 at /Users/eroesch/.julia/packages/Flux/qXNjB/src/optimise/train.jl:72 [inlined]
#  [17] gradient_(::getfield(Flux.Optimise, Symbol("##15#21")){typeof(two_stage_loss_fct),Tuple{}}, ::Tracker.Params) at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/back.jl:97
#  [18] #gradient#24(::Bool, ::Function, ::Function, ::Tracker.Params) at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/back.jl:164
#  [19] gradient at /Users/eroesch/.julia/packages/Tracker/RRYy6/src/back.jl:164 [inlined]
#  [20] macro expansion at /Users/eroesch/.julia/packages/Flux/qXNjB/src/optimise/train.jl:71 [inlined]
#  [21] macro expansion at /Users/eroesch/.julia/packages/Juno/TfNYn/src/progress.jl:133 [inlined]
#  [22] #train!#12(::getfield(Main, Symbol("##13#14")), ::Function, ::Function, ::Tracker.Params, ::Base.Iterators.Take{Base.Iterators.Repeated{Tuple{}}}, ::ADAM) at /Users/eroesch/.julia/packages/Flux/qXNjB/src/optimise/train.jl:69
#  [23] (::getfield(Flux.Optimise, Symbol("#kw##train!")))(::NamedTuple{(:cb,),Tuple{getfield(Main, Symbol("##13#14"))}}, ::typeof(Flux.Optimise.train!), ::Function, ::Tracker.Params, ::Base.Iterators.Take{Base.Iterators.Repeated{Tuple{}}}, ::ADAM) at ./none:0
#  [24] top-level scope at util.jl:156
#  [25] top-level scope at In[13]:1

# %%
pred = n_ode(u0)
scatter(t, ode_data[1,:], label = string("Observation: ", species1), grid = "off")
scatter!(t, ode_data[2,:], label = string("Observation: ", species2))
plot!(t, Flux.data(pred[1,:]), label = string("Prediction: ", species1))
plot!(t, Flux.data(pred[2,:]), label = string("Prediction: ", species2))

# %%
header = string("Collocation model")
scatter(range(1, stop = length(sa.l2s)), log.(sa.l2s), width  = 2, label = "L2 control", grid = "off")
plot!(range(1, stop = length(sa.losses)), log.(sa.losses), width  = 2, label = header)
# 5% of time even with l2s
